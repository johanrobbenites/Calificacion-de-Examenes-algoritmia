# %%
def rotar(M, n, rotaciones, capa):
  for b in range(rotaciones):
    for i in range(n):
      for j in range(n):
        aux = M[i][j]
        M[i][j] = M[n - 1 - j][i]
        M[n - 1 - j][i] = aux
    
  return M
