# %%
def Mostrar(matriz):
  print("\t","CODIGO", end=" ")
  print("\t","NOMBRE", end=" ")
  print("\t","PUNTAJE", end=" ")
  print()
  for fila in matriz:
    for valor in fila:
      print("\t", valor, end=" ")
    print()
n = int(input("Ingrese la cantidad de postulantes: "))
lista=[]
for i in range(n):
  l=[]
  codigo= input(f"Ingrese el codigo del estudiante {i+1}: ")
  nombre= input(f"Ingrese el nombre del estudiante {i+1}: ")
  puntaje= float(input("Ingrese el puntaje del estudiante: "))
  while True:
    if puntaje<=20 and puntaje>=0:
      break
    else:
      puntaje = float(input("Ingrese un valor aceptable: "))
  puntaje = (puntaje *1000)//1
  puntaje = puntaje/1000
  l.append(codigo)
  l.append(nombre)
  l.append(puntaje)
  lista.append(l)
r= len(lista)
aux = []
for i in range(r-1):
  for j in range(r-1):
    if lista[j][2] > lista[j+1][2]:
      aux = lista[j+1]
      lista[j+1] = lista[j]
      lista[j] = lista[j+1]
Mostrar(lista)
# Out:
# Ingrese la cantidad de postulantes: 1
# Ingrese el codigo del estudiante 1: 123rf4f
# Ingrese el nombre del estudiante 1: d3f34f
# Ingrese el puntaje del estudiante: 15.36
# CODIGO   NOMBRE
# 	 CODIGO 	 NOMBRE 	 PUNTAJE
# 	 123rf4f 	 d3f34f 	 15.36
