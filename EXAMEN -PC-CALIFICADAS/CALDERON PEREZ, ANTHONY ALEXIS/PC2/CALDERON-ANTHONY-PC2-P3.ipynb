# %%
n1=[]
n2=[]
while(True):
  b=int(input("Ingrese la base del sistema de numeracion que se usara: "))
  if b>=2:
    break
  else:
    print("Base invalida")
dig1=int(input("Ingrese la cantidad de dígitos del 1er numero: "))
dig2=int(input("Ingrese la cantidad de dígitos del 2do numero: "))
print("Del 1er numero")
for i in range(dig1):
  while(True):
    d=int(input(f"Digito {i+1}: "))
    if d>=0 and d<b:
      break
    else:
      print("Digito invalido")
  n1.append(d)
print("\nDel 2do numero")
for i in range(dig2):
  while(True):
    d=int(input(f"Digito {i+1}: "))
    if d>=0 and d<b:
      break
    else:
      print("Digito invalido")
  n2.append(d)

o=1
for i in n2:
  c=0
  m=1
  s=0
  for j in n1:
    k=n1[dig1-j-1]*n2[dig2-i-1]
    n=k%b
    s=s+(n*m)+(c*10*m)
    c=k//b
    m=m*10
  print(s)
  p=p+s*o
  o=o*10
print(p)
# Out:
# Ingrese la base del sistema de numeracion que se usara: 6
# Ingrese la cantidad de dígitos del 1er numero: 53041
# Ingrese la cantidad de dígitos del 2do numero: 2415
# Del 1er numero
