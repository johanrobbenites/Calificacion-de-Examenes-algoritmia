# %%
n=int(input("Ingrese la cantidad de postulantes: "))
lista=[]
codigos=[]
nombres=[]
puntos=[]
index=[]
for i in range(n):
    cod=input(f'Ingrese el codigo del alumno #{i+1} :')
    while(len(cod)>5):
        cod=input(f'Ingrese el codigo del alumno nuevamente: ')
    nombre=input(f'Ingrese el nombre del alumno #{i+1} : ')
    while(len(nombre)>50):
        nombre=input(f'Ingrese el nombre del alumno nuevamente: ')
    nota=float(input(f'Ingrese el puntaje del alumno#{i+1}: '))
    while(nota>20):
        nota=float(input(f'Ingrese el puntaje nuevamente: '))
    codigos.append(cod)
    nombres.append(nombre)
    puntos.append(nota)
#ordenando las listas:
for i in range(1,len(puntos)):
    for j in range(len(puntos)-i):
        if(puntos[j]<puntos[j+1]):
            (puntos[j],puntos[j+1])=(puntos[j+1],puntos[j])
            (codigos[j],codigos[j+1])=(codigos[j+1],codigos[j])
            (nombres[j],nombres[j+1])=(nombres[j+1],nombres[j])
#agregando puestos:
"""
c=1
index=[1]
for i in range(1,len(puntos)):
    if(puntos[i-1]==puntos[i]):
      index.append(index[len(index)-1])
    else:
      index.append(c+1)

"""

for i in range(n):
    lista.append([codigos[i],nombres[i],puntos[i]])
print("Codigo Nombre Puntaje")
for i in range(len(lista)):
    print(lista[i][0],lista[i][1],lista[i][2])
# Out:
# Ingrese la cantidad de postulantes: 3
# Ingrese el codigo del alumno #1 :p4321
# Ingrese el nombre del alumno #1 : alvaro
# Ingrese el puntaje del alumno#1: 12
# Ingrese el codigo del alumno #2 :p1231
# Ingrese el nombre del alumno #2 : perez
# Ingrese el puntaje del alumno#2: 11
# Ingrese el codigo del alumno #3 :q121
# Ingrese el nombre del alumno #3 : 15
# Ingrese el puntaje del alumno#3: 15
# Codigo   Nombre   Puntaje
# q121 15 15.0
# p4321 alvaro 12.0
# p1231 perez 11.0
