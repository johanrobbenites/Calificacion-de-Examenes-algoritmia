# %%
# 4 empleados y el codigo por empleado es 1,2,3,4 y son 3 productos y el codigo por producto es 1,2,3
em_pro=[]
for i in range(4):
  em_pro.append([0]*3)
cod_empleado=5
while cod_empleado!=0:
  cod_producto=int(input("ingrese el codigo del producto 1,2 o 3:"))
  cantidad_pro=int(input("ingrese la cantidad"))
  if(cod_producto>=1 and cod_producto<=3) and (cod_empleado>=1 and cod_empleado<=4) and cantidad_pro>0:
    #como los codigos inicializan en uno y la matriz en cero, se le resta 1
    em_pro[cod_empleado-1][cod_producto-1]=em_pro[cod_empleado-1][cod_producto-1]+cantidad_pro
  cod_empleado=int(input("ingrese 1,2,3,4 segun el empleado"))

for i in range(4):
  print("Empleado :",i+1) #i +1 por que i inica en 0 y el cod_empleados inicia en 1
  mayor,menor=em_producto[0][0],em_producto[0][0]
  for j in range(3):
    if em_producto[i][j]>mayor:
      mayor=em_producto[i][j]
    else:
      menor=em_producto[i][j]  
  print("producto", j+1,"=", em_producto[i][j])
