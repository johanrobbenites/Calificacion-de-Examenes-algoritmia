# %%
digitos1=[]
digitos2=[]
d_pro=[]
base=int(input("ingrese la base de numeracion: "))
print("La base se sistema e numeracion es :",base)
n1=int(input("Ingrese el primer numero:"))
t=n1
c=n1%10
n1=n1//10
b=n1%10
a=n1//10
digitos1.append(a)
digitos1.append(b)
digitos1.append(c)
print("los digito del primer numero  en base ",base, "son :",digitos1)
n2=int(input("Ingrese el segundo numero:"))
k=n2
z=n2%10
n2=n2//10
y=n2%10
x=n2//10
digitos2.append(x)
digitos2.append(y)
digitos2.append(z)
print("los digitos del segundo numero en base ",base, "son :",digitos2)
#hallando el producto abc x
#                     xyz
#       n1*n2      nopqrs 
producto= n1*n2
l=producto
s=producto%10
producto=producto//10
r=producto%10
producto=producto//10
q=producto%10
producto=producto//10
p=producto%10
producto= producto//10
o=producto%10
n=producto//10
if s>base:
  s=s-base
  cs=1
  while s>base:
    s=s-base
    cs=cs+1
if r+cs>base:
  r=r+cs-base
  cr=1
  while r>base:
    r=r-base
    cr=cr+1 
if q+cr>base:
  q=q+cr-base
  cq=1
  while q>base:
    q=q-base
    cq=cq+1
# Out:
# ingrese la base de numeracion: 6
# La base se sistema e numeracion es : 6
# Ingrese el primer numero:53041
# los digito del primer numero  en base  6 son : [530, 4, 1]
# Ingrese el segundo numero:2415
# los digitos del segundo numero en base  6 son : [24, 1, 5]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-09ef255891a6> in <module>()
#      45     s=s-base
#      46     cs=cs+1
# ---> 47 if r+cs>base:
#      48   r=r+cs-base
#      49   cr=1
#
# NameError: name 'cs' is not defined
