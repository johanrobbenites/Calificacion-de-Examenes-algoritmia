# %%
cadena1=[0,1,2,3,4]
cadena2=[0,1,3,5,8]
def interseccion(cadena1,cadena2):
  comun=[]
  n1=len(cadena1)
  n2=len(cadena2)
  for i in range(n1):
    for j in range(n2):
      if cadena1[i]==cadena2[j]:
        comun.append(cadena1[i])
  print("la cadena 1 es :",cadena1)
  print("la cadena 2 es: ",cadena2)
  print("los elemntos que tienen en comun son: ",comun)
def unir(cadena1,cadena2):
  union=[]
  n1=len(cadena1)
  n2=len(cadena2)
#llamando a la funcion
cad1=[]
n1=int(input("ingrese cuantos numeros quiere ingresar a la cadena 1:"))
for i in range(n1):
  a=int(input("ingrese el numero:"))
  cad1.append(a)
cad2=[]
n2=int(input("ingrese cuantos numeros quiere ingresar a la cadena 2:"))
for i in range(n2):
  b=int(input("ingrese el numero:"))
  cad2.append(b)
print(interseccion(cad1,cad2))
# Out:
# ingrese cuantos numeros quiere ingresar a la cadena 1:5
# ingrese el numero:0
# ingrese el numero:1
# ingrese el numero:2
# ingrese el numero:3
# ingrese el numero:4
# ingrese cuantos numeros quiere ingresar a la cadena 2:6
# ingrese el numero:8
# ingrese el numero:7
# ingrese el numero:5
# ingrese el numero:4
# ingrese el numero:3
# ingrese el numero:2
# la cadena 1 es : [0, 1, 2, 3, 4]
# la cadena 2 es:  [8, 7, 5, 4, 3, 2]
# los elemntos que tienen en comun son:  [2, 3, 4]
# None
