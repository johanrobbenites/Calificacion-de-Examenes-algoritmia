# %%
#trabajando con tablas, n>10,n=vendedores,x=lugar ocupado
#numero de vendedores 
with open('contenidoInfo.txt') as carpeta:
    lineas_t = sum(1 for line in carpeta)
#trabajemos con pandas para que sea mas rapido
import pandas as pd
df = pd.read_table('contenidoInfo.txt',header=None,sep=" ",columns = ["dinero","Nombre"]) 
#ordenando
df_ordenado_x_mayor_ventas = df.sort_values('dinero',ascending=False)
#lista de vendedores
puestos = 1:lineas
#completando
df_actualizada = df_ordenVentas.assign(Puesto = puestos)
df_actualizada = df_actualizada.assign(Porcent = 11-Puesto)
df_actualizada = df_actualizada.assign(Bono = dinero*Puesto)
print(df_actualizada)
# Out:
#   File "<ipython-input-1-41a29de090f4>", line 11
#     puestos = 1:lineas
#                ^
# SyntaxError: invalid syntax
