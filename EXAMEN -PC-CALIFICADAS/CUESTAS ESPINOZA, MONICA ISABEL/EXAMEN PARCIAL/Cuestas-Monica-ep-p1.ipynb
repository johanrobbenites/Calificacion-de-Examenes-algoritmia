# %%
v=[]
n=int(input("ingrese la cantidad de alumnos a ingresar:"))
for i in range(n):
  v.append([0]*4)
alumno=-1
lista_peso=[]

for i in range(n):
  codigo_a=int(input("Ingrese su código:"))
  peso=float(input("ingrese su peso:"))
  lista_peso.append(peso)
  talla=float(input("Ingrese su talla:"))
  if (codigo_a>=10 and codigo_a<=99) and peso>0 and talla>0:
    print( i,codigo_a,peso,talla)
#ordenando los pesos
for i in range(0,n):
  for j in range(i+1,n):
    if lista_peso[i]>lista_peso[j]:
      t=lista_peso[i]
      lista_peso[i]=lista_peso[j]
      lista_peso[j]=t
print(lista_peso)
# Out:
# ingrese la cantidad de alumnos a ingresar:5
# Ingrese su código:15
# ingrese su peso:82.4
# Ingrese su talla:1.78
# 0 15 82.4 1.78
# Ingrese su código:62
# ingrese su peso:82.1
# Ingrese su talla:1.91
# 1 62 82.1 1.91
# Ingrese su código:73
# ingrese su peso:73.8
# Ingrese su talla:1.77
# 2 73 73.8 1.77
# Ingrese su código:29
# ingrese su peso:73.8
# Ingrese su talla:1.82
# 3 29 73.8 1.82
# Ingrese su código:12
# ingrese su peso:60.6
# Ingrese su talla:1.55
# 4 12 60.6 1.55
# [60.6, 73.8, 73.8, 82.1, 82.4]
