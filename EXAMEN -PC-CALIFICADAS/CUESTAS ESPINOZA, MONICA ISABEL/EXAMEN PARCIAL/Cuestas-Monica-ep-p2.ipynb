# %%
n=int(input("Ingrese el numero en base 10:"))
for base in range(2,4):
  t=n
  e=n%base
  n=n//base
  d=n%base
  n=n//base
  c=n%base
  n=n//base
  b=n%base
  a=n//base
  num=e+10*d+100*c+1000*b+10000*a
  if a==e and b==d:
    print(f"El numero es capicua en la base: {base} (pues es {num})")
  else:
    print(f"El numero no es capicua en la base: {base} (pues es {num})")
for base in range(4,6):
  z=n%base
  n=n//base
  y=n%base
  x=n//base
  numero= z+ 10*y+100*x
  if x==z:
    print(f"El numero es capicua en la base: {base} (pues es {numero})")
  else:
    print(f"El numero no es capicua en la base: {base} (pues es {numero})")
for base in range(6,10): 
  m=n%base
  n=n//base
  p=n
  numer= m+10*p
  if m==p:
     print(f"El numero es capicua en la base: {base} (pues es {numer})")
  else:
     print(f"El numero no es capicua en la base: {base} (pues es {numer})")
