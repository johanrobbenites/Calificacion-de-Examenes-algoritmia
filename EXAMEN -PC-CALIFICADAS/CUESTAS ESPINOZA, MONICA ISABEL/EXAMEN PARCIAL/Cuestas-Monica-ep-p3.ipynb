# %%
a=[]
for i in range(2):
  a.append([0]*3)
print(a)
for i in range(2):
  for j in range(3):
    a[i][j]=int(input("ingrese el elemento d[%d,%d] de la matriz=:"%(i,j)))
print(a)
print("matriz rectangular")
print(a[0])
print(a[1])
a_1=[]
for i in range(3):
  a.append([0]*2)
print(a_1)
for i in range(3):
  for j in range(2):
    a_1[i][j]=a[j][i+1]
print(a)
print("matriz rectangular")
print(a[0])
print(a[1])
# Out:
# [[0, 0, 0], [0, 0, 0]]
# ingrese el elemento d[0,0] de la matriz=:1
# ingrese el elemento d[0,1] de la matriz=:2
# ingrese el elemento d[0,2] de la matriz=:3
# ingrese el elemento d[1,0] de la matriz=:4
# ingrese el elemento d[1,1] de la matriz=:5
# ingrese el elemento d[1,2] de la matriz=:6
# [[1, 2, 3], [4, 5, 6]]
# [1, 2, 3]
# [4, 5, 6]
