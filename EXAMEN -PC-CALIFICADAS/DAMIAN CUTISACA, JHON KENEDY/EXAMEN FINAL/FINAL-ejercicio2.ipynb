# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
f=open("bonos.txt","r")
c = []
cap =""
for i in range(11):
  a = f.readlines(i+1)
  c.append(a)

vac1 = []
vac2 = []
vac3 = []
vac4 = []
vac5 = []
vac6 = []
vac7 = []
vac8 = []
vac9 = []
vac10 = []
vac11 = []
datos = []
lista1 = []
lista2 = []
lista3 = []
lista4 = []
lista5 = []
lista6 = []
lista7 = []
lista8 = []
lista9 = []
lista10 = []
lista11 = []
cap0 = ""
cap1 = ""
cap2 = ""
cap3 = ""
cap4 = ""
cap5 = ""
cap6 = ""
cap7 = ""
cap8 = ""
cap9 = ""
cap10 = ""
cap11 = ""
c1 = str(c[0])
c2 = str(c[1])
c3 = str(c[2])
c4 = str(c[3])
c5 = str(c[4])
c6 = str(c[5])
c7 = str(c[6])
c8 = str(c[7])
c9 = str(c[8])
c10 = str(c[9])
c11 = str(c[10])

def elimin(d,c1):
  for i in c1:
    d.append(i) 
  d.pop(0)
  d.pop(0)
  d.pop(len(d)-1)
  d.pop(len(d)-1)
  d.pop(len(d)-1)
  d.pop(len(d)-1)
  return d
d1 = elimin(vac1,c1)
def num(d,lista1,cap):
  for i in range(8):
    prim = d[i]
    lista1.append(prim)
  for i in lista1:
    cap = cap + i 
  return cap
num1 = num(d1,lista1,cap0)
aea = float(num1) + 15
d2 = elimin(vac2,c2)
num2 = num(vac2,lista2,cap1)
d3 = elimin(vac3,c3)
num3 = num(vac3,lista3,cap2)
d4 = elimin(vac4,c4)
num4 = num(vac4,lista4,cap3)
d5 = elimin(vac5,c5)
num5 = num(vac5,lista5,cap4)
d6 = elimin(vac6,c6)
num6 = num(vac6,lista6,cap5)
d7 = elimin(vac7,c7)
num7 = num(vac7,lista7,cap6)
d8 = elimin(vac8,c8)
num8 = num(vac8,lista8,cap7)
d9 = elimin(vac9,c9)
num9 = num(vac9,lista9,cap8)
d10 = elimin(vac10,c10)
num10 = num(vac10,lista10,cap9)
d11 = elimin(vac11,c11)
num11 = num(vac11,lista11,cap10)
lista_bono = [num1 , num2, num3,num4,num5,num6,num7,num8,num9,num10,num11]
lista_bonocop = [num1 , num2, num3,num4,num5,num6,num7,num8,num9,num10,num11]
mayores = []
mayor = lista_bono[0]
n = 0
orden =[]
def mayormas(lista_bono,mayor,mayores):
  for i in range(1,len(lista_bono)):
     if mayor < lista_bono[i]:
       mayor = lista_bono[i]
  mayores.append(mayor)    
  lista_bono.remove(mayor)
while(n<5):
  mayormas(lista_bono,mayor,mayores)
  n = n +1
for i in range(len(mayores)):
  for j in range(len(lista_bonocop)):
    if mayores[i] == lista_bonocop[j]:
      orden.append(j)
listavac1 = []
listavac2 = []
listavac3 = []
listavac4 = []
listavac5 = []
listavac6 = []
listavac7 = []
listavac8 = []
listavac9 = []
listavac10 = []
listavac11 = []
capvac1 = ""
capvac2 = ""
capvac3 = ""
capvac4 = ""
capvac5 = ""
capvac6 = ""
capvac7 = ""
capvac8 = ""
capvac9 = ""
capvac10 = ""
capvac11 = ""
def nombre(d,lista1,cap): 
  for i in range(9,len(d)):
    prim = d[i]
    lista1.append(prim)
  for i in lista1:
    cap = cap + i 
  return cap
nombre1 = nombre(d1,listavac1,capvac1)
nombre2 = nombre(d2,listavac2,capvac2)
nombre3 = nombre(d3,listavac3,capvac3)
nombre4 = nombre(d4,listavac4,capvac4)
nombre5 = nombre(d5,listavac5,capvac5)
nombre6 = nombre(d6,listavac6,capvac6)
nombre7 = nombre(d7,listavac7,capvac7)
nombre8 = nombre(d8,listavac8,capvac8)
nombre9 = nombre(d9,listavac9,capvac9)
nombre10 = nombre(d10,listavac10,capvac10)
nombre11 = nombre(d11,listavac11,capvac11)
nombres =[nombre1,nombre2,nombre3,nombre4,nombre5,nombre6,nombre7,nombre8,nombre9,nombre10,nombre11]
for i in range(5):
  print(mayores[i],nombres[int(orden[i])],i+1, float(mayores[i])*((10-i)/100) , 10-i,"%")
# Out:
# 79562.30 Carlos Perez 1 7956.2300000000005 10 %
# 68940.50 Joel Rojas 2 6204.6449999999995 9 %
# 49125.60 Lorena Torres 3 3930.048 8 %
# 48749.40 Juan Millones 4 3412.4580000000005 7 %
# 42067.00 Julia Rios 5 2524.02 6 %
