# %%
num = int(input("INGRESE UN NUMERO :"))
a = num
b = [ ] #los numeros ya cambiados
nuev = 0
c = 0
d = nuev
con1 = 0
for j in range(2 , 10):
 while num >= j:
    d1 = num % j
    num = num // j
    nuev = nuev + d1*(10**c)
    c = c + 1
    if num < j : 
      nuev = nuev + num*(10**c)
      b.append(nuev)
 num = a
 nuev = d
 c = 0
print(b)
b1 = b
cont = 1
con = [] #la cantidad de digitos
for i in range(8):
 while b[i] >= 10 :
   b[i] = b[i] / 10
   cont = cont + 1
   if b[i] < 10:
    con.append(cont)
 cont = 1   
dg = [] #los digitos en si
r = 0
b.clear()
for j in range(2 , 10):
 while num >= j:
    d1 = num % j
    num = num // j
    nuev = nuev + d1*(10**c)
    c = c + 1
    if num < j : 
      nuev = nuev + num*(10**c)
      b.append(nuev)
 num = a
 nuev = d
 c = 0
for n in range(8):
  while r <= con[n] :
    dig = (b1[n] // (10**(con[n]-r))) % 10
    dg.append(dig)    
    r = r + 1   
  dg.remove(0)  
  r = 0
  for g1 in range(con[n]):
    if dg[g1] == dg[con[n]-1-g1]:
     con1 = con1 + 1
     if con1 == con[n]-1 :
        print("El numero es capicua en la base", n+2 ,"(pues el numero es ", b[n],")")
  con1 = 0
  dg.clear()
# Out:
# INGRESE UN NUMERO :154
# [10011010, 12201, 2122, 1104, 414, 310, 232, 181]
# El numero es capicua en la base 6 (pues el numero es  414 )
# El numero es capicua en la base 8 (pues el numero es  232 )
# El numero es capicua en la base 9 (pues el numero es  181 )
