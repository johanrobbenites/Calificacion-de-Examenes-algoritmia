# %%
lista = []
for i in range(4):
  lista.append([0]*3)
print(lista)
codemp = -1
while codemp != 0 :
  codp = int(input("INGRESE CODIGO DEL PRODUCTO DEL 1 AL 3:"))
  cant = int(input("INGRESE LA CANTIDAD :"))
  if (codemp >= 1 and codemp <= 4 ) and ( codp >= 1 and codp <= 3) and cant > 0:
    lista[codemp-1][codp-1] = lista[codemp-1][codp-1] + cant 
  codemp = int(input("INGRESE CODIGO DEL EMPLEADO DEL 1 AL 4:"))
36
for i in range(4):
  print("EMPLEADO :" , i+1)
  for j in range(3):
    print("Codigo producto : ",j+1, " ",lista[i][j])
