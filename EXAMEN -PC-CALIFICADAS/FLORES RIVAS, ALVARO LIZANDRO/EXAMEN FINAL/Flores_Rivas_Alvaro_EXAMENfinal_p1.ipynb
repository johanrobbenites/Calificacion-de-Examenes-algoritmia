# %%
with open("ALGORITMIA.txt", "r") as tf:
	lines = tf.read().split('\n')

W = list()
V = list()
U = list()
for line in lines:
	new_lines = line.split()
	
	for palabra in new_lines:
		
		if palabra[0] == "U":
		
			U.append(palabra[1:])
		elif palabra[0] == "W":
	
			W.append(palabra[1:])
		elif palabra[0] == "V":
		
			V.append(palabra[1:])

def suma(myList):
		
		listSum = 0

		for number in myList:
		    listSum += int(number)

		return listSum


promedio_W = suma(W)/len(W)
print("El promedio de la seccion U es: ", promedio_W)

promedio_U = suma(U)/len(U)
print("El promedio de la seccion U es: ", promedio_U)

promedio_V = suma(V)/len(V)
print("El promedio de la seccion V es: ", promedio_V)


contador_W = 0
contador_V = 0
contador_U = 0
for nota in W:
	if int(nota) > 9: 
		contador_W = contador_W + 1

for nota in U:
	if int(nota) > 9: 
		contador_U = contador_U + 1

for nota in V:
	if int(nota) > 9: 
		contador_V = contador_V + 1

print("El numero de alumnos aprobados en la seccion U es de: ", contador_U)
print("El numero de alumnos aprobados en la seccion V es de: ", contador_V)
print("El numero de alumnos aprobados en la seccion W es de: ", contador_W)
tf.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-2587293a6bb2> in <module>()
# ----> 1 with open("ALGORITMIA.txt", "r") as tf:
#       2         lines = tf.read().split('\n')
#       3
#       4 W = list()
#       5 V = list()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ALGORITMIA.txt'
