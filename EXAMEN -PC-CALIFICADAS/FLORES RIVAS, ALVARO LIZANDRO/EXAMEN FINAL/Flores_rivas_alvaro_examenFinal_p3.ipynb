# %%
def r(oracion):
    if oracion == "":
        return oracion
    else:
        return r(oracion[1:]) + oracion[0]

oracion=input("Ingrese la oracion: ")
linea=""
for i in oracion:
    if i!=" ":
        linea=linea+i

print(r(linea))
# Out:
# Ingrese la oracion: Yo hago Yoga hoy
# yohagoYogahoY
