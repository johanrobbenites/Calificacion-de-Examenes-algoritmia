# %%
list1 = [1, 2, 3, 2, 4, 5]
list2 = [0, 2, 2, 4, 6]
interseccion = []
for x in list1:
    if x in list2:
        interseccion.append(x)
print(interseccion)

list4=list1+list2
union = []
 
for i in list4:
    if i not in union:
        union.append(i)

print(union)
# Out:
# [2, 2, 4]
# [1, 2, 3, 4, 5, 0, 6]
