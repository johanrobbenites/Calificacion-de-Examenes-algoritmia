# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Yo hago Yoga hoy
    
def r(oracion):
    if oracion == "":
        return oracion
    else:
        return r(oracion[1:]) + oracion[0]

oracion=input("Ingrese la oracion: ")
linea=""
for i in oracion:
    if i!=" ":
        linea=linea+i
linea1= linea.lower()
palabra=r(linea1)

def espalindromo_2(palabra):
      a = 0
      b = len(palabra) - 1
      for i in range(0,len(palabra)):
          if palabra[a] == palabra[b]:
              a +=1
              b -=1
          else:
              return False         
      return True
print()
if espalindromo_2(palabra):
    print(oracion)
    print("Sin espacios en blanco y todo en minúsculas sería:")
    print(palabra)
    print("Al invertirla da")
    print(palabra)
    print("por lo tanto, es palíndroma")
else:
    print(oracion,"no es palíndroma")
# Out:
# Ingrese la oracion: Yo hago Yoga hoy
#
# Yo hago Yoga hoy
# Sin espacios en blanco y todo en minúsculas sería:
# yohagoyogahoy
# Al invertirla da
# yohagoyogahoy
# por lo tanto, es palíndroma

# %%
def r(oracion):
    if oracion == "":
        return oracion
    else:
        return r(oracion[1:]) + oracion[0]

oracion=input("Ingrese la oracion: ")
linea=""
for i in oracion:
    if i!=" ":
        linea=linea+i
linea1= linea.lower()
print(r(linea1))
# Out:
# Ingrese la oracion: Yo hago yoga hoy
# yohagoyogahoy

# %%
def espalindromo(palabra):
  a = 0
  b = len(palabra) - 1
#Yo hago Yoga hoy
  for i in range(0,len(palabra)):
      if palabra[a] == palabra[b]:
          a +=1
          b -=1
      else:
          return False

  return True
palabra=input("ingrese una palabra:")

if espalindromo(palabra):
    print(1)
else:
    print(2)
# Out:
# ingrese una palabra:yohagoyogahoy
# 1

# %%
def r(oracion):
    if oracion == "":
        return oracion
    else:
        return r(oracion[1:]) + oracion[0]

def espalindromo_2(palabra):
      a = 0
      b = len(palabra) - 1
      for i in range(0,len(palabra)):
          if palabra[a] == palabra[b]:
              a +=1
              b -=1
          else:
              return False         
      return True

oracion=input("Ingrese la oracion: ")
linea=""
for i in oracion:
    if i!=" ":
        linea=linea+i
linea1= linea.lower()
palabra=r(linea1)

if espalindromo_2(palabra):
    print(1)
else:
    print(2)
