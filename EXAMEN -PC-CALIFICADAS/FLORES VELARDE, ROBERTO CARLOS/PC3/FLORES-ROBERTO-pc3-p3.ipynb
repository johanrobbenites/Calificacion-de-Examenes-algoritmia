# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def conjunto(cA,cB):
  A=[]    
  aux1=cA.split(";")
  cont=""       
  for x in aux1:
      for i in x:
          if i.isdigit() or i=='-':
              cont+=i
      A.append(int(cont))
      cont=""
  print(A)       
  
  aux2=cB.split(";")
  cont=""   
  B=[]    
  for x in aux2:
      for i in x:
          if i.isdigit() or i=='-':
              cont+=i
      B.append(int(cont))
      cont=""
  print(B)  
  interseccion = []
  for x in A:
      if x in B:
          interseccion.append(x)
  union_repetidos = A + B
  union = []
  for i in union_repetidos:
      if i not in union:
          union.append(i)
  for i in range(1,len(union)):
        for j in range(0,len(union)-i):
            if(union[j+1] < union[j]):
                aux=union[j]
                union[j]=union[j+1]
                union[j+1]=aux
  print(union)  
  for i in range(1,len(interseccion)):
        for j in range(0,len(interseccion)-i):
            if(interseccion[j+1] < interseccion[j]):
                aux=interseccion[j]
                interseccion[j]=interseccion[j+1]
                interseccion[j+1]=aux
  print(interseccion)  
  return union,interseccion
cA="A={-41;-2;0;1;123}"
cB="B={-3;-2;1;2}"
print(conjunto(cA,cB))
# Out:
# [-41, -2, 0, 1, 123]
# [-3, -2, 1, 2]
# [-41, -3, -2, 0, 1, 2, 123]
# [-2, 1]
# ([-41, -3, -2, 0, 1, 2, 123], [-2, 1])

# %%
def conjunto(cA,cB):
  A=[]
  for i in cA:
    A.append(i)
  B=[]
  for i in cB:
    B.append(i)
  interseccion = []
  for x in A:
      if x in B:
          interseccion.append(x)
  union_repetidos = A + B
  union = []
  for i in union_repetidos:
      if i not in union:
          union.append(i)
  for i in range(1,len(union)):
        for j in range(0,len(union)-i):
            if(union[j+1] < union[j]):
                aux=union[j]
                union[j]=union[j+1]
                union[j+1]=aux
  for i in range(1,len(interseccion)):
        for j in range(0,len(interseccion)-i):
            if(interseccion[j+1] < interseccion[j]):
                aux=interseccion[j]
                interseccion[j]=interseccion[j+1]
                interseccion[j+1]=aux
  print(f"La primera cadena recibe el conjunto:\nA = {cA}")
  print(f"La segunda cadena recibe el conjunto:\nB = {cB}")
  print("Las dos última cadenas devuelven:")
  print(f"UNION = {union}")
  print(f"INTERSECCION = {interseccion}")
  return union,interseccion
cA={-41,-2,0,1,123}
cB={-3,-2,1,2}
print(conjunto(cA,cB))
# Out:
# La primera cadena recibe el conjunto:
# A = {0, 1, -41, 123, -2}
# La segunda cadena recibe el conjunto:
# B = {1, 2, -3, -2}
# Las dos última cadenas devuelven:
# UNION = [-41, -3, -2, 0, 1, 2, 123]
# INTERSECCION = [-2, 1]
# ([-41, -3, -2, 0, 1, 2, 123], [-2, 1])

# %%
A=[3,4,16,1,12,5,4,7]
for i in range(1,len(A)):
        for j in range(0,len(A)-i):
            if(A[j+1] < A[j]):
                aux=A[j]
                A[j]=A[j+1]
                A[j+1]=aux
print(A)
# Out:
# [1, 3, 4, 4, 5, 7, 12, 16]

# %%
a="A={-41; -2;0;1;123}"
b="B={-3;-2;1;2}"

lista1=[]    
aux1=a.split(";")
cont=""       
for x in aux1:
    for i in x:
        if i.isdigit():
            cont+=i
    lista1.append(int(cont))
    cont=""
print(lista1)       

aux2=b.split(";")
cont=""   
lista2=[]    
for x in aux2:
    for i in x:
        if i.isdigit():
            cont+=i
    lista2.append(int(cont))
    cont=""
print(lista2)
# Out:
# [41, 2, 0, 1, 123]
# [3, 2, 1, 2]

# %%
cA="A={-41;-2;0;1;123}"
cB="B={-3;-2;1;2}"
A=[]    
aux1=cA.split(";")
cont=""       
for x in aux1:
    for i in x:
        if i.isdigit() or i=='-':
            cont+=i
    A.append(int(cont))
    cont=""
print(A)       

aux2=cB.split(";")
cont=""   
B=[]    
for x in aux2:
    for i in x:
        if i.isdigit() or i=='-':
            cont+=i
    B.append(int(cont))
    cont=""
print(B)
# Out:
# [-41, -2, 0, 1, 123]
# [-3, -2, 1, 2]
