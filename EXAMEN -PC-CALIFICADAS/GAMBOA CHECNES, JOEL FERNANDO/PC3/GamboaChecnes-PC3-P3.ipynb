# %%
def ingresando():
  A=[]
  v=int(input("INGRESE VALOR AL CONJUNTO A: "))
  A.append(str(v))
  r=input("DESEA SEGUIR INGRESANDO VALORES AL CONJUNTO A? (si/no): }")
  while r=="si":
    while True: 
      m=v
      valor=int(input("INGRESE VALOR AL CONJUNTO A: "))
      if valor>v:
        A.append(str(valor))
        v=valor
        break
      else:
        print("INGRESE UN VALOR MAYOR AL ANTERIOR")
    r=input("DESEA SEGUIR INGRESANDO VALORES AL CONJUNTO A? (si/no): ")
  B=[]
  b=int(input("INGRESE VALOR AL CONJUNTO B: "))
  B.append(str(b))
  rpta=input("DESEA SEGUIR INGRESANDO VALORES AL CONJUNTO B? (si/no): ")
  while rpta=="si":
    while True: 
      k=b
      val=int(input("INGRESE VALOR AL CONJUNTO B: "))
      if val>b:
        B.append(str(val))
        k=val
        break
      else:
        print("INGRESE UN VALOR MAYOR AL ANTERIOR")
    rpta=input("DESEA SEGUIR INGRESANDO VALORES AL CONJUNTO B? (si/no): ")
  union=
  a=" ; ".join(A)
  b=" ; ".join(B)
  print("A=","{",a,"}")
  print("B=","{",b,"}")
m=ingresando()
# Out:
# INGRESE VALOR AL CONJUNTO A: 5
# DESEA SEGUIR INGRESANDO VALORES AL CONJUNTO A? (si/no): }si
# INGRESE VALOR AL CONJUNTO A: 9
# DESEA SEGUIR INGRESANDO VALORES AL CONJUNTO A? (si/no): si
# INGRESE VALOR AL CONJUNTO A: 12
# DESEA SEGUIR INGRESANDO VALORES AL CONJUNTO A? (si/no): no
# INGRESE VALOR AL CONJUNTO B: 7
# DESEA SEGUIR INGRESANDO VALORES AL CONJUNTO B? (si/no): si
# INGRESE VALOR AL CONJUNTO B: 6
# INGRESE UN VALOR MAYOR AL ANTERIOR
# INGRESE VALOR AL CONJUNTO B: 10
# DESEA SEGUIR INGRESANDO VALORES AL CONJUNTO B? (si/no): si
# INGRESE VALOR AL CONJUNTO B: 62
# DESEA SEGUIR INGRESANDO VALORES AL CONJUNTO B? (si/no): no
# A= { 5;9;12 }
# B= { 7;10;62 }
