# %%
n = int(input("INGRESE LA CANTIDAD DE CADENAS A LEER: "))
lista = []
for i in range(n):
  cadena = input("INGRESE LA CADENA: ")
  lista.append(cadena)
print(lista)
caracteres = []
for cadenas in lista:
  for letras in cadenas:
    caracteres.append(letras)
caracteres = list(set(caracteres))
for i in range(len(caracteres)-1,-1,-1):
  if caracteres[i] == " ":
    print(caracteres.pop(i))
for palabra in lista:
  for x in palabra:
    if i in caracteres:
      for n in caracteres:
        cont =  lista.count("a")
print(cont)
# Out:
# INGRESE LA CANTIDAD DE CADENAS A LEER: 3
# INGRESE LA CADENA: hola como estas
# INGRESE LA CADENA: ruby o python
# INGRESE LA CADENA: lenguaje
# ['hola como estas', 'ruby o python', 'lenguaje']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-73ddf75e7a5d> in <module>()
#      18       for n in caracteres:
#      19         cont =  lista.count("a")
# ---> 20 print(cont)
#
# NameError: name 'cont' is not defined
