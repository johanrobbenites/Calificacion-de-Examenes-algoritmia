# %%
f=open("alumno.txt","a")
op="s"
while op =="s":
	monto=float(input("Ingrese el monto: "))
	nomb=input("Nombre del empleado: ")  
	linea=str(monto)+"\t"+nomb+"\n"
	f.write(linea)
	op=input("desea continuar (s/n) ")
f.close()
print()


f=open("alumno.txt","r")
print("MONTO\tNOMBRE"+"\t"*2+"PTO\tBONO\tPORC\n")
for i in f:
	print(i)
f.close()

montos = {}
for i in f:
  montos[nomb]=monto
print(montos)
for valor in montos.values():
    if valor > mayor:
      mayor = valor
def get_key(val):
    for key, value in montos.items():
         if val == value:
             return key
    return get_key(mayor)
# Out:
# Ingrese el monto: 24816.00
# Nombre del empleado: Pedro Castillo
# desea continuar (s/n) n
#
# MONTO	NOMBRE		PTO	BONO	PORC
#
# 48749.4	Juan Millones    1    4874.94    10%
#
# 48749.4	Mario Torres     1    4874.94    10%
#
# 42067.0	Julia Rios       3    3365.36     8%
#
# 38942.5	Felipe Salas     4    2725.97     7%
#
# 36450.0	Roberto Zela     5    2187.00     6%
#
# 36450.0	Rosa Garcia      5    2187.00     6%
#
#
#
# 24816.0	Pedro Castillo
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-0bdc1db7d4fe> in <module>()
#      18
#      19 montos = {}
# ---> 20 for i in f:
#      21   montos[nomb]=monto
#      22 print(montos)
#
# ValueError: I/O operation on closed file.
