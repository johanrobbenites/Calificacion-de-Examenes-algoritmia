# %%
num = int(input("INGRESE UN NUEMRO EN BASE 10: "))
# Si la base es 2
dig2 = []

if num == 2:
  num2 = num
  while num2 > 2:
    num2 = num2 // 2
    dig2.append(num2)
  res2 = num2 % 2
  dig2.append(res2)
tam_list2 = len.dig2
for i in dig2:
  if i == (i + (tam_list2 -1)) and i+1 == (i + (tam_list2 -2)):
    print(f"EL NUMERO {num} ES CAPICUA EN BASE 2.")
# Si la base es 3
dig3 = []
if num == 3:
  num3 = num
  while num3 > 3:
    num3 = num3 // 3
    dig3.append(num3)
  res3 = num3 % 3
  dig3.append(num3)
tam_list3 = len.dig3
for i in dig3:
  if i == (i + (tam_list3 -1)) and i+1 == (i + (tam_list3 -2)):
    print(f"EL NUMERO {num} ES CAPICUA EN BASE 3.")
# Si la base es 4
dig4 = []
if num == 4:
  num4 = num
  while num4 > 4:
    num4 = num4 // 4
    dig4.append(num3)
  res4 = num4 % 4
  dig4.append(num4)
tam_list4 = len.dig4
for i in dig4:
  if i == (i + (tam_list4 -1)) and i+1 == (i + (tam_list4 -2)):
    print(f"EL NUMERO {num} ES CAPICUA EN BASE 4.")
# Si la base es 5
dig5 = []
if num == 5:
  num4 = num
  while num5 > 5:
    num5 = num5 // 5
    dig5.append(num5)
  res5 = num % 5
  dig5.append(num4)
print(dig5)
tam_list5 = len.dig5
for i in dig5:
  if i == (i + (tam_list5 -1)) and i+1 == (i + (tam_list5 -2)):
    print(f"EL NUMERO {num} ES CAPICUA EN BASE 5.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     723         """
# --> 724         parts = [self.recv(flags, copy=copy, track=track)]
#     725         # have first part already, only loop while more to receive
#
# ...
