# %%
matriz = [
    [2, 5, 7], 
    [4, 3, 9],
    ]
def rotar(matriz):
  mat_rotada = []
  for i in range(len(matriz[0])):
    mat_rotada.append([])
    for j in range(len(matriz)):
      mat_rotada[i].append(matriz[len(matriz)-1-j][i])
    mat_rotada
print("------------------")
for fila in matriz:
  for x in fila:
    print(x, end=" ")
  print()
print("------------------")
rot1 = rotar(matriz)
for fila in matriz:
  for x in fila:
    print(x, end=" ")
  print()
print("------------------")    
rot2 = rotar(rot1)
for fila in rot1:
  for x in fila:
    print(x, end=" ")
  print()
print("------------------")   
rot3 = rotar(rot2)
for fila in rot2:
  for x in fila:
    print(x, end=" ")
  print()
print("------------------")  
rot4 = rotar(rot3)
for fila in rot3:
  for x in fila:
    print(x, end=" ")
  print()
print("------------------")
# Out:
# ------------------
# 2 5 7
# 4 3 9
# ------------------
# 2 5 7
# 4 3 9
# ------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-29a5876287f6> in <module>()
#      22   print()
#      23 print("------------------")
# ---> 24 rot2 = rotar(rot1)
#      25 for fila in rot1:
#      26   for x in fila:
#
# <ipython-input-1-29a5876287f6> in rotar(matriz)
#       5 def rotar(matriz):
#       6   mat_rotada = []
# ----> 7   for i in range(len(matriz[0])):
#       8     mat_rotada.append([])
#       9     for j in range(len(matriz)):
#
# TypeError: 'NoneType' object is not subscriptable
