# %% [markdown]
# Pregunta 1:

# %%
alumnos = []

n = int(input("Ingrese cantidad de alumnos: "))
for i in range(n):
  alumnos.append([0]*3)
print(alumnos)

for i in range(n):
  coda = int(input("Ingrese el código del alumno: "))
  peso = float(input("Ingrese el peso del alumno: "))
  talla = float(input("Ingrese la talla del alumno: "))
  if (coda>=10 and coda<100):
    alumnos[i][0] = coda
    alumnos[i][1] = peso
    alumnos[i][2] = talla

mayor = 0
while n != 0:
  for i in range(n):
    if alumnos[i][1] >= 0:
      alumnos[0][1] = alumnos[i][1]
      |



print(alumnos)
