# %%
v = []
m = int(input("Numero de filas: "))
n = int(input("Numero de columnas: "))
for i in range(m):
  v.append([0]*n)
for i in range(m):
  for j in range(n):
    v[i][j] = int(input("Introduzca un numero: "))
print(v)

v = []
for i in range(n):
  v.append([0]*m)
for i in range(m):
  for j in range(n):
  v[i][j] = v[j][i]
print(v)

v = []
for i in range(m):
  v.append([0]*n)
for i in range(m):
  for j in range(n):
  v[i][j] = v[j][i]
print(v)

v = []
for i in range(n):
  v.append([0]*m)
for i in range(m):
  for j in range(n):
  v[i][j] = v[j][i]
print(v)
# Out:
# Numero de filas: 2
# Numero de columnas: 3
# Introduzca un numero: 2
# Introduzca un numero: 5
# Introduzca un numero: 7
# Introduzca un numero: 4
# Introduzca un numero: 3
# Introduzca un numero: 9
# [[2, 5, 7], [4, 3, 9]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-054ee45ca2cc> in <module>()
#      12 for i in range(n):
#      13   v.append([0]*m)
# ---> 14   v[i][j] = v[j][i]
#      15 print(v)
#      16
#
# IndexError: list index out of range
