# %%
#
n = int(input("Ingrese un numero en base 10: "))
b = 1
while (b >= 1 and b <9) and c!=0:
  b = b + 1
  c = n // b
  r = n % b
  print(c)
# Out:
# Ingrese un numero en base 10: 23
# 11
# 7
# 5
# 4
# 3
# 3
# 2
# 2
