# %%
"""
Escriba un programa para leer en arreglos los datos de n alumnos, donde n<=30. Por cada alumno debe leer:
código (número de 2 cifras), peso y talla, luego debe mostrar los datos ordenados descendentemente por peso
y para los empates en peso mostrar ordenado ascendentemente por talla. Luego debe insertar los datos de un
nuevo estudiante de modo tal que se mantenga el ordenamiento.
"""
n = int(input("Inserte el número de alumnos (<=30): "))
alumnos = []
if n<=30:
  for i in range(n):
    codigo = int(input(f"CÓDIGO {i} : "))
    if codigo >= 10 and codigo <= 99:
      alumnos.append(codigo)
    else:
      print("EL CÓDIGO DEBE SER UN NÚMERO DE 2 CIFRAS")
      break
    talla = float(input(f"TALLA {i} :"))
    alumnos.append(talla)
    peso = float(input(f"PESO {i} : "))
    alumnos.append(peso)
    ordena = []
    for i in range(n):     
      ordena.append(peso) 
    for i in range(0,n):
      for j in range(i+1, n):
        if ordena[i] > ordena[j]:
          t = ordena[i]
          ordena[i] = ordena[j]
          ordena[j] = t
    print(f"LA LISTA ORDENADA DE PESOS ES {ordena}")
else:
  print("LA CANTIDAD DE ALUMNOS DEBE SER MENOR O IGUAL A 30")
