# %%
"""
Escriba un programa que lea n cadenas de tamaño no mayor a 50 caracteres, y 
realice un histograma con las frecuencias del caracter 'a' hasta el caracter 
'z'. No se consideran las vocales tildadas, ni la 'ñ'. 
"""
from collections import defaultdict
def contar_caracteres(cadena):
  contador = 0
  while cadena[contador:]:
    contador +=1
  return contador
cad = []
n = int(input("Ingrese el número de cadenas: "))
for i in range(n):
  x = input("Ingrese la cadena: ")
  if contar_caracteres(x) < 50:
    cad.append(x)
  else:
    print(" --- LAS CADENAS NO DEBEN CONTENER MÁS DE 50 CARACTERES --- ")
    break


contador = defaultdict(int)
for caracteres in x:
  contador[caracteres] += 1

for caracteres in sorted(contador, key = contador.get, reverse =True):
  if contador[caracteres] > 1:
    print("El caracter %s se repite %i" %(caracteres, contador[caracteres]))
# Out:
# Ingrese el número de cadenas: 4
# Ingrese la cadena: hola como estas
# Ingrese la cadena: juan
# Ingrese la cadena: maria
# Ingrese la cadena: zuta
