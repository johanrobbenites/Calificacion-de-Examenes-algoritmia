# %%
9m1 = []
n1 = []
m = int(input("Ingrese el valor de m filas: "))
n = int(input("Ingrese el valor de n columnas: "))
for i in range(m):
  elementom = int(input("Ingrese el elemento: "))
  m1.append(elementom)
for j in range(n):
  elementon = int(input("Ingrese el elemento: "))
  n1.append(elementon)
print(m1)
print(n1)
# Out:
# Ingrese el valor de m filas: 2
# Ingrese el valor de n columnas: 3
# Ingrese el elemento: 2
# Ingrese el elemento: 5
# Ingrese el elemento: 7
# Ingrese el elemento: 4
# Ingrese el elemento: 3
# [2, 5]
# [7, 4, 3]
