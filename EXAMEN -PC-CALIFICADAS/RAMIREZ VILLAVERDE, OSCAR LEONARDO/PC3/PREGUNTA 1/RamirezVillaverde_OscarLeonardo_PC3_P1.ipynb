# %%
import operator
n = int(input("Ingrese el valor de n: "))
postulantes = {}
for i in range(n):
  codigo = input("Ingrese código de postulante: ")
  while len(codigo) != 5:
    print("!ERROR!")
    codigo = input("Ingrese código de postulante: ")
  nombre = input("Ingresar nombre de postulante: ")
  while len(nombre) > 50:
    print("!ERROR!")
    nombre = input("Ingresar nombre de postulante: ")
  puntaje = float(input("Ingrese puntaje de postulante: "))
  while puntaje < 0 or puntaje > 20:
    print("!ERROR")
    puntajebeta = float(input("Ingrese puntaje de postulante: "))
  postulantes[codigo] = puntaje
postulantesfinal = sorted(postulantes.items(), key=operator.itemgetter(1), reverse=True)
print("Listado de notas")
for codigo in postulantes:
  print(codigo, postulantes[codigo])
