# %%
def conv(num):
    resultado = "" 
    while num > 0 :
      residuo = num % b
      resultado = resultado + str(residuo)
      num = num // b
    return resultado[::-1]  
N = int(input("ingrese el numero:"))
b = 2
s = 0
cont = 0
if (N > 0):
  while(b < 9):
    x = conv(N)  
    num = str(x)
    d = len(num) 
    b = b+1
    if (d % 2 ==0):
      v = int(d/2)
      alm = 0
      for i in range(v):
        if( num[i]==num[d-i-1]):
          alm = alm +1
      if(alm== v):
         print(f"el numero es capicua en base {b-1} (pues numero es {x})")
      
    else:
     v = int(d-1/2)
     alm = 0
     for i in range(v):
       if( num[i]==num[d-i-1]):
         alm = alm +1
     if(alm== v):
       print(f"el numero es capicua en base {b-1}  (pues numero es {x})")
# Out:
# ingrese el numero:154
# el numero es capicua en base 6  (pues numero es 414)
# el numero es capicua en base 8  (pues numero es 232)
