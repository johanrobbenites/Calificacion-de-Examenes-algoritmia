# %%
n = int(input("ingrese las notas : "))
a = [0]*n
print(a)
cont = 0
cont1= 0
for i in range(n):
  a[i] = int(input("ingrese las notas :")) 
  if a[i]>= 10  :
    cont = cont + 1
print(a)
aprobados = (cont/n)*100
print("promedio de aprobados :",round(aprobados,2),"%")
while (aprobados <=70):
  for i in range(n):
    if (a[i]< 20) :
      a[i] = a[i] +1 
    if (a[i]>= 10) :
        cont1 = cont1 + 1
  
  aprobados = (cont1/n)*100
  print(a)
  print("promedio de aprobados:",round(aprobados,2),"%")
  print(n)
  print(cont1)
  cont1 = 0
# Out:
# ingrese las notas : 7
# [0, 0, 0, 0, 0, 0, 0]
# ingrese las notas :7
# ingrese las notas :9
# ingrese las notas :14
# ingrese las notas :8
# ingrese las notas :6
# ingrese las notas :5
# ingrese las notas :10
# [7, 9, 14, 8, 6, 5, 10]
# promedio de aprobados : 28.57 %
# [8, 10, 15, 9, 7, 6, 11]
# promedio de aprobados: 42.86 %
# 7
# 3
# [9, 11, 16, 10, 8, 7, 12]
# promedio de aprobados: 57.14 %
# 7
# 4
# [10, 12, 17, 11, 9, 8, 13]
# promedio de aprobados: 71.43 %
# 7
# 5
