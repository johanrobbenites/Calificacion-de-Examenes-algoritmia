# %%
#Escriba un programa que lea los datos de n postulantes y por cada uno lea su codigo, su nombre y su puntaje
#Luego determine el orden de merito segun el puntaje. Considere que si 2 o mas postulantes empatan en puntaje
#tienen el mismo orden de merito. Ejemplo: si n=6 y los datos ingresados fueran:
n = int(input("Ingrese el numero de alumnos: "))
codigos = []
nombres = []
puntajes = []
for i in range(n):
  nombre = input("Ingrese el nombre del alumno numero "+str(i+1)+": ")
  nombres.append(nombre)
  codigo = input("Ingrese el codigo del alumno numero "+str(i+1)+": ")
  codigos.append(codigo)
  puntaje = float(input("Ingrese el puntaje del alumno numero "+str(i+1)+": "))
  puntajes.append(puntaje)
x = []
for i in range(n):
  x.append([0]*3)
for j in range(3):
  for i in range(n):
    if(j == 0):
      x[i][j] = nombres[i]
    if(j == 1):
      x[i][j] = codigos[i]
    if(j == 2):
      x[i][j] = puntajes[i]
for i in range(n):
  for j in range(3):
    print(x[i][j],end=" ")
    print()
for i in range(1, len(puntajes)):
    for j in range(len(puntajes)-i):
      if(puntajes[j]<puntajes[j+1]):
        aux = puntajes[j]
        puntajes[j] = puntajes[j+1]
# Out:
# Ingrese el numero de alumnos: 2
# Ingrese el nombre del alumno numero 1: Marco
# Ingrese el codigo del alumno numero 1: S1234
# Ingrese el puntaje del alumno numero 1: 15.365
# Ingrese el nombre del alumno numero 2: Manuel
# Ingrese el codigo del alumno numero 2: P4321
# Ingrese el puntaje del alumno numero 2: 12.456
# Marco
# S1234
# 15.365
# Manuel
# P4321
# 12.456
