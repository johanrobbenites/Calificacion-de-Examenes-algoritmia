# %%
def primXcarc(x,v):
  v=v+"f"
  aux=""
  aux2=0
  while(aux2<=x or v[i]!="f"):
    aux=aux+v[aux2]
    aux2=aux2+1
  return aux

def primXdec(x,n):
  v=str(n)
  for i in len(v):
    s=i+x+1
    if v[i]=="." and (len(v)>a):
      for a in len(v):
        v.pop()
  return v
n=int(input("número de estudiantes: "))
A={}
print("CODIGO\tNOMBRE\tPUNTAJE")
for i in range(n):
  codigo=input("codigo: ")
  codigo=primXcarc(5,codigo)

  nombre=input("nombre: ")
  nombre=primXcarc(50,nombre)

  puntaje=input("puntaje: ")
  puntaje=primXdec(3,puntaje)
  A[codigo]=[nombre,puntaje]
  print(codigo,"\t",nombre,"\t",puntaje)
# Out:
# número de estudiantes: 5
# CODIGO	NOMBRE	PUNTAJE
# codigo: M1234
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-02d362224875> in <module>()
#      21 for i in range(n):
#      22   codigo=input("codigo: ")
# ---> 23   codigo=primXcarc(5,codigo)
#      24
#      25   nombre=input("nombre: ")
#
# <ipython-input-2-02d362224875> in primXcarc(x, v)
#       4   aux2=0
#       5   while(aux2<=x or v[i]!="f"):
# ----> 6     aux=aux+v[aux2]
#       7     aux2=aux2+1
#       8   return aux
#
# IndexError: string index out of range
