# %%
n=int(input("número de cadenas: "))
c=[]
for i in range(n):
  cad=input(f"cadena {i+1} :\t")
  c.append(cad)
carac={}
for j in range(97,123):
  carac[chr(i)]=0
for k in range(n):
  for l in range(len(c[k])):
    if ord(c[k][l])<123 and 96<ord(c[k][l]):
      carac[c[k][l]]+=1
for i in range(len(carac)):
  if(carac[i]>0):
    print(chr(97+i),". ",carac[i],carac[i]*"*")
# Out:
# número de cadenas: 1
# cadena 1 :	fra
# f
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-50e8ce97215f> in <module>()
#      11     print(c[k][l])
#      12     if ord(c[k][l])<123 and 96<ord(c[k][l]):
# ---> 13       carac[c[k][l]]+=1
#      14 for i in range(len(carac)):
#      15   if(carac[i]>0):
#
# KeyError: 'f'

# %%
ord("a")<3
# Out:
# False
