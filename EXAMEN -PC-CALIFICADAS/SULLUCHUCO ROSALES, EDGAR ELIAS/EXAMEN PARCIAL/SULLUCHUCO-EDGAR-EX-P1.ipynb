# %%
n=0
while(n<1 or n>30):
  n=int(input("número de alumnos(menor a 30):"))
L=[]
for i in range(n):
  cod=int(input("Ingrese el codigo: "))
  peso=float(input("Ingrese el peso: "))
  talla=float(input("Ingrese el talla: "))
  L.append([cod,peso,talla])
for i in range(0,n):
  for j in range(0,n-i-1):
    if(L[j][1]<L[j+1][1]):
      aux=L[j][1]
      L[j][1]=L[j+1][1]
      L[j+1][1]=aux
    else:
      if(L[j][1]==sL[j+1][1]):
        if(L[j][2]>L[j+1][2]):
          aux=L[j][2]
          L[j][2]=L[j+1][2]
          L[j+1][2]=aux
print("\tCODIGO\tPESO\tTALLA")
for i in range(n):
  print(f"\t{L[i][0]}\t{L[i][1]}\t{L[i][2]}")
#ingresar datos del nuevo estudiante
print("nuevo estudiante")
cod=int(input("Ingrese el codigo: "))
peso=float(input("Ingrese el peso: "))
talla=float(input("Ingrese el talla: "))
L.append([])
for i in range(n-1,0,-1):
  L[i+1]=L[i]
  if(L[i-1][1]>peso):
    L[i]=[cod,peso,talla]
    i=0
    break;
print("\tCODIGO\tPESO\tTALLA")
for i in range(n+1):
  print(f"\t{L[i][0]}\t{L[i][1]}\t{L[i][2]}")
