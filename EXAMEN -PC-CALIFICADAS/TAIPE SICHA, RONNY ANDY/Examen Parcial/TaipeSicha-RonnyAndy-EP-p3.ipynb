# %%
a=int(input("ingrese el numero de filas :"))
b=int(input("ingrese el numero de columnas :"))
m=[]
for i in range(a):
  m.append([0]*b)
for i in range(a):
  for j in range(b):
    c=int(input("ingrese el numero en la posicion"))
    m[i][j]=m[i][j]+c
print(m)
for x in range(4):
  for y in range(3):
    m=[[m[j][i]for j in range(len(m))]for i in range(len(m[0])-1,-1,-1)]
  print(m)
# Out:
# ingrese el numero de filas :2
# ingrese el numero de columnas :3
# ingrese el numero en la posicion2
# ingrese el numero en la posicion5
# ingrese el numero en la posicion7
# ingrese el numero en la posicion4
# ingrese el numero en la posicion3
# ingrese el numero en la posicion9
# [[2, 5, 7], [4, 3, 9]]
# [[4, 2], [3, 5], [9, 7]]
# [[9, 3, 4], [7, 5, 2]]
# [[7, 9], [5, 3], [2, 4]]
# [[2, 5, 7], [4, 3, 9]]
