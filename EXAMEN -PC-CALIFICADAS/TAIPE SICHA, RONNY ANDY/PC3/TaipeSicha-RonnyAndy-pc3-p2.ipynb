# %%
while True:
  a=input("ingrese una cadena de menos de 50 caracteres ")
  if len(a)<50:
    break
def buscar(x):
  m=a.count(x)
  return m
for i in range(97,123):
  print(chr(i),buscar(chr(i)),"*"*buscar(chr(i)))
# Out:
# ingrese una cadena de menos de 50 caracteres lenguaje de progrmacion
# a 2 **
# b 0
# c 1 *
# d 1 *
# e 3 ***
# f 0
# g 2 **
# h 0
# i 1 *
# j 1 *
# k 0
# l 1 *
# m 1 *
# n 2 **
# o 2 **
# p 1 *
# q 0
# r 2 **
# s 0
# t 0
# u 1 *
# v 0
# w 0
# x 0
# y 0
# z 0
