# %%
from google.colab import drive
drive.mount("/content/drive/")

arch=open("alumnos.txt","w")
n=int(input("ingrese la cantidad de alumnos que quiere agregar: "))
for i in range(n):
  nom=input("ingrese el codigo de estudiante, el codigo de curso y el promedio final: ")
  nom=nom +"\n"
  arch.write(nom)
arch.close()

l1=open("alumnos.txt","r")
v=l1.readlines()
l1.close()

c=[]
for i in range(len(v)):
  a=v[i]
  m="\n"
  a=a.replace(m,"")
  b=a.split(" ")
  c.append(b)

d=[]
for i in range(len(c)):
  if c[i][0] not in d:
    d.append(c[i][0])

for i in d:
  k=0
  m=0
  for j in range(len(c)):
    if i == c[j][0]:
      if int(c[j][2])<10:
        k=k+1
      else:
        m=m+1
  print("el alumno",i,"aprobo",m,"cursos y desaprobo",k,"cursos")

e=[]
f=[]
for i in range(len(c)):
  if c[i][1] not in d:
    e.append(c[i][1])

for i in e:
  l=0
  h=0
  for j in range(len(c)):
    if i == c[j][1]:
      if int(c[j][2])<10:
        l=l+1
  f.append(l)

cantidad=max(f)
for i in range(len(f)):
  if f[i]==cantidad:
    print("el curso con mas desaprobados es",e[i])
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# ingrese la cantidad de alumnos que quiere agregar: 6
# ingrese el codigo de estudiante, el codigo de curso y el promedio final: 111 CB101 17
# ingrese el codigo de estudiante, el codigo de curso y el promedio final: 111 SI102 6
# ingrese el codigo de estudiante, el codigo de curso y el promedio final: 222 CB101 16
# ingrese el codigo de estudiante, el codigo de curso y el promedio final: 222 SI102 7
# ingrese el codigo de estudiante, el codigo de curso y el promedio final: 333 CB101 20
# ingrese el codigo de estudiante, el codigo de curso y el promedio final: 333 SI102 5
# el alumno 111 aprobo 1 cursos y desaprobo 1 cursos
# el alumno 222 aprobo 1 cursos y desaprobo 1 cursos
# el alumno 333 aprobo 1 cursos y desaprobo 1 cursos
# el curso con mas desaprobados es SI102
# el curso con mas desaprobados es SI102
# el curso con mas desaprobados es SI102
