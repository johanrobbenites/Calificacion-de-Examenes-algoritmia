# %%
n=int(input("ingrese la cantidad de numeros del arreglo: "))
b=[]
for i in range(n):
  a=int(input("ingrese un numero: "))
  b.append(a)
def encontrar(b,c):
  try:
    c=int(input("ingrese el numero a buscar: "))
    idx=b.index(c)
    m=idx+1
    print("la posicion del numero empezando a contar desde el 1 es :",m)
  except:
    print("-1")
encontrar(b,c)
# Out:
# ingrese la cantidad de numeros del arreglo: 6
# ingrese un numero: 2
# ingrese un numero: 5
# ingrese un numero: 7
# ingrese un numero: 5
# ingrese un numero: 2
# ingrese un numero: 8
# ingrese el numero a buscar: 3
# -1
